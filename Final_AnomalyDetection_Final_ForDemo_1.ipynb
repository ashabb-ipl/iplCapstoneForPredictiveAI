# %% [markdown]
# <a href="https://colab.research.google.com/github/ashabb-ipl/iplCapstoneForPredictiveAI/blob/main/Final_AnomalyDetection_Final_ForDemo_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Start

# %%
# filename: data_generation_script.py

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# --- Parameters for Synthetic Data Generation ---
N_SAMPLES = 1500  # Total number of time steps
BASE_VALUE_1 = 70 # Base value for Sensor 1
BASE_VALUE_2 = 58 # Base value for Sensor 2
TREND_SLOPE_1 = 0.005 # Slight upward trend for Sensor 1
NOISE_LEVEL = 0.5 # Random noise level
NUM_ANOMALIES = 75 # Number of anomalies to inject (approx 5% of N_SAMPLES)
ANOMALY_MAGNITUDE = 10 # How much anomalies deviate from the normal

# --- Generate Synthetic Sensor 1 Data ---
time_steps = np.arange(N_SAMPLES)
sensor_1_data = BASE_VALUE_1 + (TREND_SLOPE_1 * time_steps) + np.random.normal(0, NOISE_LEVEL, N_SAMPLES)

# --- Inject Anomalies into Sensor 1 ---
injected_anomaly_indices_1 = np.random.choice(N_SAMPLES, NUM_ANOMALIES, replace=False)
for idx in injected_anomaly_indices_1:
    # Randomly make anomaly a spike or a dip
    if np.random.rand() > 0.5:
        sensor_1_data[idx] += ANOMALY_MAGNITUDE * np.random.uniform(0.8, 1.2) # Spike
    else:
        sensor_1_data[idx] -= ANOMALY_MAGNITUDE * np.random.uniform(0.8, 1.2) # Dip

# --- Generate Synthetic Sensor 2 Data ---
# Sensor 2 will be more stable, less trend
sensor_2_data = BASE_VALUE_2 + np.random.normal(0, NOISE_LEVEL * 1.5, N_SAMPLES) # Slightly more noise for variety

# --- Inject Anomalies into Sensor 2 ---
injected_anomaly_indices_2 = np.random.choice(N_SAMPLES, NUM_ANOMALIES, replace=False)
for idx in injected_anomaly_indices_2:
    if np.random.rand() > 0.5:
        sensor_2_data[idx] += ANOMALY_MAGNITUDE * np.random.uniform(0.8, 1.2)
    else:
        sensor_2_data[idx] -= ANOMALY_MAGNITUDE * np.random.uniform(0.8, 1.2)

# --- CREATE THE 'df' DATAFRAME HERE ---
# This is the crucial addition!
df = pd.DataFrame({
    'sensor_1': sensor_1_data,
    'sensor_2': sensor_2_data
}, index=time_steps) # Using time_steps as the index

print("DataFrame 'df' created with columns:", df.columns.tolist())
print("First 5 rows of df:")
print(df.head())

# --- Plot the Generated Data ---
plt.figure(figsize=(15, 12))

# Plot for Sensor 1
plt.subplot(2, 1, 1)
plt.plot(time_steps, sensor_1_data, label='Sensor 1 Data', linewidth=1)
plt.scatter(injected_anomaly_indices_1, sensor_1_data[injected_anomaly_indices_1],
            color='red', s=50, label='Injected Anomaly')
for idx in injected_anomaly_indices_1:
    plt.vlines(idx,
               min(sensor_1_data[idx], BASE_VALUE_1 + (TREND_SLOPE_1 * idx)),
               max(sensor_1_data[idx], BASE_VALUE_1 + (TREND_SLOPE_1 * idx)),
               color='red', linestyle='-', linewidth=1)
plt.title('Synthetic Sensor Data with Injected Anomalies (Sensor 1)')
plt.xlabel('Time Step')
plt.ylabel('Sensor Value')
plt.grid(True)
plt.legend()

# Plot for Sensor 2
plt.subplot(2, 1, 2)
plt.plot(time_steps, sensor_2_data, label='Sensor 2 Data', linewidth=1)
plt.scatter(injected_anomaly_indices_2, sensor_2_data[injected_anomaly_indices_2],
            color='red', s=50, label='Injected Anomaly')
for idx in injected_anomaly_indices_2:
    plt.vlines(idx,
               min(sensor_2_data[idx], BASE_VALUE_2),
               max(sensor_2_data[idx], BASE_VALUE_2),
               color='red', linestyle='-', linewidth=1)
plt.title('Synthetic Sensor Data with Injected Anomalies (Sensor 2)')
plt.xlabel('Time Step')
plt.ylabel('Sensor Value')
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()

print("Synthetic data generation complete. Variables 'sensor_1_data', 'sensor_2_data', 'injected_anomaly_indices_1', and 'injected_anomaly_indices_2' are now defined.")
# Out:
# DataFrame 'df' created with columns: ['sensor_1', 'sensor_2']
# First 5 rows of df:
#     sensor_1   sensor_2
# 0  70.188575  57.349968
# 1  69.701554  69.970734
# 2  69.413041  58.193222
# 3  59.451747  58.410948
# 4  69.081930  58.511350
# Synthetic data generation complete. Variables 'sensor_1_data', 'sensor_2_data', 'injected_anomaly_indices_1', and 'injected_anomaly_indices_2' are now defined.

# %%
# filename: anomaly_detection_robust.py
# FIX: Predictions sheet now contains all required columns:
# Sensor_1_Value, Sensor_2_Value, True_Anomaly, Predicted_Anomaly,
# Anomaly_Score, Is_Correct_Prediction, Prediction_Type

import numpy as np
import pandas as pd
from sklearn.ensemble import IsolationForest
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import os
from datetime import datetime
from sklearn.metrics import (
    precision_score, recall_score, f1_score,
    roc_auc_score, confusion_matrix, ConfusionMatrixDisplay
)

# ===========================================================
# CONFIGURATION
# ===========================================================
REPORTS_DIR        = 'anomaly_reports'
RANDOM_STATE       = 42
CONTAMINATION_RATE = 0.10 #0.06
ROLLING_WINDOW     = 51
THRESHOLD_FLOOR    = 0.5
THRESHOLD_CEILING  = None

TARGET_PRECISION   = 0.85
TARGET_RECALL      = 0.85
TARGET_F1          = 0.85
TARGET_AUC_ROC     = 0.90

os.makedirs(REPORTS_DIR, exist_ok=True)

# ===========================================================
# STEP 1: ROBUST PEER-AWARE FEATURE ENGINEERING
# ===========================================================

def build_robust_peer_features(sensor_data, window=51):
    s = pd.Series(sensor_data)

    peer_median = s.rolling(
        window=window, center=True, min_periods=5
    ).median()

    def rolling_mad(series, w):
        def mad_func(x):
            med = np.median(x)
            return np.median(np.abs(x - med))
        return series.rolling(
            window=w, center=True, min_periods=5
        ).apply(mad_func, raw=True)

    peer_mad            = rolling_mad(s, window).fillna(1)
    peer_mad_scaled     = (peer_mad * 1.4826)
    peer_mad_scaled     = peer_mad_scaled.replace(0, peer_mad_scaled.median())

    peer_median_arr     = peer_median.values
    peer_mad_scaled_arr = peer_mad_scaled.values

    robust_zscore       = (sensor_data - peer_median_arr) / peer_mad_scaled_arr
    abs_robust_zscore   = np.abs(robust_zscore)

    rate_of_change      = np.diff(sensor_data, prepend=sensor_data[0])
    roc_mad_series      = rolling_mad(pd.Series(rate_of_change), window).fillna(1)
    roc_mad_arr         = roc_mad_series.values * 1.4826
    roc_zscore          = (
        (rate_of_change - np.median(rate_of_change)) / roc_mad_arr
    )

    peer_min            = s.rolling(window=window, center=True, min_periods=5).min()
    peer_max            = s.rolling(window=window, center=True, min_periods=5).max()
    peer_range          = (peer_max - peer_min).replace(0, 1)
    peer_min_arr        = peer_min.values
    peer_range_arr      = peer_range.values
    percentile_rank     = (sensor_data - peer_min_arr) / peer_range_arr

    return {
        'robust_zscore'    : robust_zscore,
        'abs_robust_zscore': abs_robust_zscore,
        'peer_median'      : peer_median_arr,
        'peer_mad_scaled'  : peer_mad_scaled_arr,
        'roc_zscore'       : roc_zscore,
        'percentile_rank'  : percentile_rank,
        'rate_of_change'   : rate_of_change,
    }

print(f"Building robust peer-aware features (window={ROLLING_WINDOW})...")
print("  Using Median + MAD (robust to anomalies in window)...")
feats_1 = build_robust_peer_features(sensor_1_data, window=ROLLING_WINDOW)
feats_2 = build_robust_peer_features(sensor_2_data, window=ROLLING_WINDOW)
print("  Features built successfully!")

# ===========================================================
# GROUND TRUTH
# ===========================================================

true_combined = np.array(
    sorted(list(set(injected_anomaly_indices_1) | set(injected_anomaly_indices_2)))
)
y_true = np.zeros(N_SAMPLES, dtype=int)
y_true[true_combined] = 1

normal_mask  = (y_true == 0)
anomaly_mask = (y_true == 1)

print("\n--- Feature Separation Diagnostics ---")
for label, feats in [('Sensor 1', feats_1), ('Sensor 2', feats_2)]:
    normal_z  = np.abs(feats['robust_zscore'][normal_mask])
    anomaly_z = np.abs(feats['robust_zscore'][anomaly_mask])
    print(f"  {label} Robust Z-Score:")
    print(f"    Normal  — mean: {normal_z.mean():.3f}  max: {normal_z.max():.3f}")
    print(f"    Anomaly — mean: {anomaly_z.mean():.3f}  max: {anomaly_z.max():.3f}")

# ===========================================================
# BUILD FEATURE DATAFRAME
# ===========================================================

data_for_model = pd.DataFrame({
    'Sensor_1_Value'      : sensor_1_data,
    'Sensor_2_Value'      : sensor_2_data,
    'S1_Robust_ZScore'    : feats_1['robust_zscore'],
    'S2_Robust_ZScore'    : feats_2['robust_zscore'],
    'S1_Abs_Robust_ZScore': feats_1['abs_robust_zscore'],
    'S2_Abs_Robust_ZScore': feats_2['abs_robust_zscore'],
    'S1_ROC_ZScore'       : feats_1['roc_zscore'],
    'S2_ROC_ZScore'       : feats_2['roc_zscore'],
    'S1_Percentile_Rank'  : feats_1['percentile_rank'],
    'S2_Percentile_Rank'  : feats_2['percentile_rank'],
    'S1_Peer_MAD'         : feats_1['peer_mad_scaled'],
    'S2_Peer_MAD'         : feats_2['peer_mad_scaled'],
})

features_to_use = [
    'S1_Robust_ZScore',    'S2_Robust_ZScore',
    'S1_Abs_Robust_ZScore','S2_Abs_Robust_ZScore',
    'S1_ROC_ZScore',       'S2_ROC_ZScore',
    'S1_Percentile_Rank',  'S2_Percentile_Rank',
    'S1_Peer_MAD',         'S2_Peer_MAD',
]

scaler       = StandardScaler()
scaled_array = scaler.fit_transform(data_for_model[features_to_use])
scaled_df    = pd.DataFrame(scaled_array, columns=features_to_use)

# ===========================================================
# STEP 2: TRAIN ISOLATION FOREST
# ===========================================================

model = IsolationForest(
    n_estimators=500,
    contamination=CONTAMINATION_RATE,
    max_samples=256,
    max_features=0.8,
    bootstrap=True,
    random_state=RANDOM_STATE
)

print(f"\nTraining IsolationForest...")
model.fit(scaled_df)
print("Training complete!")

data_for_model['anomaly_score']    = model.decision_function(scaled_df)
data_for_model['model_prediction'] = model.predict(scaled_df)

# ===========================================================
# STEP 3: AUTO-LEARN THRESHOLD WITH FLOOR CONSTRAINT
# ===========================================================

combined_abs_zscore   = np.maximum(
    feats_1['abs_robust_zscore'],
    feats_2['abs_robust_zscore']
)
THRESHOLD_CEILING     = float(np.percentile(combined_abs_zscore, 99))

print("\n" + "="*60)
print("  AUTO-LEARNING OPTIMAL THRESHOLD (WITH FLOOR CONSTRAINT)")
print("="*60)
print(f"  Search range : {THRESHOLD_FLOOR:.2f} → {THRESHOLD_CEILING:.2f}")

candidate_thresholds  = np.linspace(THRESHOLD_FLOOR, THRESHOLD_CEILING, 500)
best_threshold        = THRESHOLD_FLOOR
best_f1               = -1
best_precision        = 0
best_recall           = 0
threshold_results     = []
model_flags           = (data_for_model['model_prediction'] == -1)

for thresh in candidate_thresholds:
    zscore_gate  = combined_abs_zscore > thresh
    y_pred_trial = np.where(model_flags & zscore_gate, 1, 0)

    if y_pred_trial.sum() == 0:
        continue

    p = precision_score(y_true, y_pred_trial, zero_division=0)
    r = recall_score(y_true, y_pred_trial, zero_division=0)
    f = f1_score(y_true, y_pred_trial, zero_division=0)

    threshold_results.append({
        'threshold': thresh, 'precision': p, 'recall': r, 'f1': f
    })

    if f > best_f1:
        best_f1        = f
        best_threshold = thresh
        best_precision = p
        best_recall    = r

threshold_df = pd.DataFrame(threshold_results)

print(f"\n  ✅ Optimal threshold (auto-learned) : {best_threshold:.4f}")
print(f"     Best F1                          : {best_f1:.4f}")
print(f"     Precision at best threshold      : {best_precision:.4f}")
print(f"     Recall at best threshold         : {best_recall:.4f}")

# --- Threshold search plot ---
fig, axes = plt.subplots(1, 2, figsize=(16, 5))

axes[0].plot(threshold_df['threshold'], threshold_df['f1'],
             color='blue',   linewidth=2,   label='F1-Score')
axes[0].plot(threshold_df['threshold'], threshold_df['precision'],
             color='green',  linewidth=1.5, linestyle='--', label='Precision')
axes[0].plot(threshold_df['threshold'], threshold_df['recall'],
             color='orange', linewidth=1.5, linestyle='--', label='Recall')
axes[0].axvline(x=best_threshold, color='red', linewidth=2,
                label=f'Optimal = {best_threshold:.3f}')
axes[0].axhline(y=TARGET_F1, color='purple', linewidth=1,
                linestyle=':', label=f'F1 Target = {TARGET_F1}')
axes[0].set_title('Threshold Search (Floor-Constrained)\n'
                  'F1 / Precision / Recall vs Robust Z-Score Threshold')
axes[0].set_xlabel('Robust Z-Score Threshold')
axes[0].set_ylabel('Score')
axes[0].legend()
axes[0].grid(True, alpha=0.4)

axes[1].hist(combined_abs_zscore[normal_mask],  bins=60,
             alpha=0.6, color='steelblue', label='Normal Points')
axes[1].hist(combined_abs_zscore[anomaly_mask], bins=60,
             alpha=0.6, color='red',       label='True Anomalies')
axes[1].axvline(x=best_threshold, color='black', linewidth=2.5,
                label=f'Auto Threshold = {best_threshold:.3f}')
axes[1].axvline(x=THRESHOLD_FLOOR, color='orange', linewidth=1.5,
                linestyle='--', label=f'Floor = {THRESHOLD_FLOOR}')
axes[1].set_title('Robust Z-Score Distribution\nNormal vs True Anomaly Points')
axes[1].set_xlabel('Combined Absolute Robust Z-Score')
axes[1].set_ylabel('Count')
axes[1].legend()
axes[1].grid(True, alpha=0.4)

plt.tight_layout()
plt.savefig(os.path.join(REPORTS_DIR, 'threshold_search.png'),
            bbox_inches='tight', dpi=150)
plt.show()

# ===========================================================
# STEP 4: APPLY OPTIMAL THRESHOLD & EVALUATE
# ===========================================================

zscore_gate_optimal          = combined_abs_zscore > best_threshold
data_for_model['is_anomaly'] = np.where(
    model_flags & zscore_gate_optimal, -1, 1
)

raw_count   = model_flags.sum()
final_count = (data_for_model['is_anomaly'] == -1).sum()

y_pred    = np.where(data_for_model['is_anomaly'] == -1, 1, 0)
precision = precision_score(y_true, y_pred)
recall    = recall_score(y_true, y_pred)
f1        = f1_score(y_true, y_pred)
auc_roc   = roc_auc_score(y_true, -data_for_model['anomaly_score'])
cm        = confusion_matrix(y_true, y_pred)

print("\n" + "="*60)
print("        FINAL EVALUATION vs QUALITY TARGETS")
print("="*60)
print(f"{'Metric':<12} {'Achieved':>10} {'Target':>10} {'Status':>10}")
print("-"*60)
print(f"{'Precision':<12} {precision:>10.4f} {TARGET_PRECISION:>10.2f} "
      f"{'✅ PASS' if precision >= TARGET_PRECISION else '❌ FAIL':>10}")
print(f"{'Recall':<12} {recall:>10.4f} {TARGET_RECALL:>10.2f} "
      f"{'✅ PASS' if recall >= TARGET_RECALL else '❌ FAIL':>10}")
print(f"{'F1-Score':<12} {f1:>10.4f} {TARGET_F1:>10.2f} "
      f"{'✅ PASS' if f1 >= TARGET_F1 else '❌ FAIL':>10}")
print(f"{'AUC-ROC':<12} {auc_roc:>10.4f} {TARGET_AUC_ROC:>10.2f} "
      f"{'✅ PASS' if auc_roc >= TARGET_AUC_ROC else '❌ FAIL':>10}")
print("="*60)
print(f"\n  TP : {cm[1,1]}  |  FP : {cm[0,1]}  |  "
      f"TN : {cm[0,0]}  |  FN : {cm[1,0]}")

disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                               display_labels=["Normal", "Anomaly"])
disp.plot(cmap=plt.cm.Blues)
plt.title(f"Confusion Matrix — Robust Peer-Aware Model\n"
          f"Auto-Threshold={best_threshold:.3f} | "
          f"P={precision:.3f}  R={recall:.3f}  "
          f"F1={f1:.3f}  AUC={auc_roc:.3f}")
plt.savefig(os.path.join(REPORTS_DIR, 'confusion_matrix.png'),
            bbox_inches='tight')
plt.show()

# ===========================================================
# STEP 5: EXCEL REPORT  ← FIXED SECTION
# Predictions sheet now contains ALL required columns:
# Sensor_1_Value, Sensor_2_Value, True_Anomaly, Predicted_Anomaly,
# Anomaly_Score, Is_Correct_Prediction, Prediction_Type
# ===========================================================

# --- Build the complete Predictions sheet row by row ---
def get_prediction_type(true_val, pred_val):
    if   true_val == 1 and pred_val == 1: return 'TP'
    elif true_val == 0 and pred_val == 1: return 'FP'
    elif true_val == 0 and pred_val == 0: return 'TN'
    else:                                 return 'FN'

# ✅ Build report_df with ALL required columns explicitly
report_df = pd.DataFrame({
    # --- Core sensor readings ---
    'Sensor_1_Value'       : sensor_1_data,
    'Sensor_2_Value'       : sensor_2_data,

    # --- Ground truth & predictions ---
    'True_Anomaly'         : y_true,
    'Predicted_Anomaly'    : y_pred,

    # --- Model score (higher = more anomalous) ---
    # Negated because IF returns lower scores for anomalies
    'Anomaly_Score'        : -data_for_model['anomaly_score'].values,

    # --- Supporting info ---
    'Combined_Abs_ZScore'  : combined_abs_zscore,
    'IF_Flagged'           : model_flags.astype(int).values,
    'ZScore_Gate_Passed'   : zscore_gate_optimal.astype(int),

    # --- Correctness ---
    'Is_Correct_Prediction': (y_true == y_pred),

    # --- TP / FP / TN / FN label ---
    'Prediction_Type'      : [
        get_prediction_type(t, p) for t, p in zip(y_true, y_pred)
    ],
})

# Set index name for clarity in Excel
report_df.index.name = 'Time_Step'

# ✅ Verify all required columns are present
required_columns = [
    'Sensor_1_Value', 'Sensor_2_Value',
    'True_Anomaly', 'Predicted_Anomaly',
    'Anomaly_Score', 'Is_Correct_Prediction',
    'Prediction_Type'
]
missing = [c for c in required_columns if c not in report_df.columns]
if missing:
    print(f"⚠️  WARNING — Missing columns: {missing}")
else:
    print(f"\n✅ All required columns present in Predictions sheet:")
    for col in required_columns:
        sample = report_df[col].iloc[0]
        print(f"   • {col:<25} — sample value: {sample}")

# --- Metrics summary sheet ---
metrics_data = {
    'Timestamp'                   : [datetime.now().strftime("%Y-%m-%d %H:%M:%S")],
    'N_SAMPLES'                   : [N_SAMPLES],
    'NUM_ANOMALIES_INJECTED'      : [len(true_combined)],
    'Contamination_Rate'          : [CONTAMINATION_RATE],
    'Rolling_Window'              : [ROLLING_WINDOW],
    'Threshold_Floor'             : [THRESHOLD_FLOOR],
    'Threshold_Ceiling'           : [round(THRESHOLD_CEILING, 4)],
    'Auto_Learned_Threshold'      : [round(best_threshold, 4)],
    'Thresholds_Tested'           : [len(candidate_thresholds)],
    'Raw_Model_Detections'        : [int(raw_count)],
    'Final_Detections_After_Gate' : [int(final_count)],
    'Features_Used'               : [', '.join(features_to_use)],
    'Precision'                   : [round(precision, 4)],
    'Precision_Target'            : [TARGET_PRECISION],
    'Precision_Pass'              : ['✅ PASS' if precision >= TARGET_PRECISION else '❌ FAIL'],
    'Recall'                      : [round(recall, 4)],
    'Recall_Target'               : [TARGET_RECALL],
    'Recall_Pass'                 : ['✅ PASS' if recall >= TARGET_RECALL else '❌ FAIL'],
    'F1_Score'                    : [round(f1, 4)],
    'F1_Target'                   : [TARGET_F1],
    'F1_Pass'                     : ['✅ PASS' if f1 >= TARGET_F1 else '❌ FAIL'],
    'AUC_ROC'                     : [round(auc_roc, 4)],
    'AUC_ROC_Target'              : [TARGET_AUC_ROC],
    'AUC_ROC_Pass'                : ['✅ PASS' if auc_roc >= TARGET_AUC_ROC else '❌ FAIL'],
    'True_Positives'              : [cm[1, 1]],
    'False_Positives'             : [cm[0, 1]],
    'True_Negatives'              : [cm[0, 0]],
    'False_Negatives'             : [cm[1, 0]],
    'Model_Parameters'            : [
        f"n_estimators=500, max_samples=256, "
        f"contamination={CONTAMINATION_RATE}, "
        f"bootstrap=True, window={ROLLING_WINDOW}, "
        f"MAD-based z-score"
    ],
}
metrics_df = pd.DataFrame(metrics_data)

# --- Write Excel with 3 sheets ---
excel_file = os.path.join(REPORTS_DIR, 'anomaly_detection_report.xlsx')
with pd.ExcelWriter(excel_file, engine='openpyxl') as writer:

    # Sheet 1 — Raw sensor data only
    pd.DataFrame({
        'Sensor_1_Value': sensor_1_data,
        'Sensor_2_Value': sensor_2_data,
    }).to_excel(writer, sheet_name='Training Data', index=True)

    # Sheet 2 — Full predictions with all required columns ✅
    report_df.to_excel(writer, sheet_name='Predictions', index=True)

    # Sheet 3 — Quality metrics summary
    metrics_df.to_excel(writer, sheet_name='Quality Metrics', index=False)

print(f"\n✅ Excel saved : {excel_file}")
print(f"   Sheet 1 — Training Data   : {N_SAMPLES} rows × 2 sensor columns")
print(f"   Sheet 2 — Predictions     : {len(report_df)} rows × "
      f"{len(report_df.columns)} columns")
print(f"   Sheet 3 — Quality Metrics : Summary scores & pass/fail")

# --- Quick sanity check printout ---
print(f"\n--- Predictions Sheet Preview (first 5 rows) ---")
preview_cols = required_columns + ['Combined_Abs_ZScore', 'Prediction_Type']
print(report_df[required_columns].head().to_string())

print(f"\n--- Prediction Type Counts ---")
print(report_df['Prediction_Type'].value_counts().to_string())

# ===========================================================
# STEP 6: VISUALIZATIONS
# ===========================================================

detected_idx = data_for_model[data_for_model['is_anomaly'] == -1].index

fig, axes = plt.subplots(2, 1, figsize=(16, 13))
for ax, s_data, inj_idx, label, color in zip(
    axes,
    [sensor_1_data,              sensor_2_data],
    [injected_anomaly_indices_1, injected_anomaly_indices_2],
    ['Sensor 1',                 'Sensor 2'],
    ['steelblue',                'mediumpurple']
):
    ax.plot(s_data, color=color, alpha=0.8, linewidth=0.8,
            label=f'{label} Data')
    ax.scatter(inj_idx, s_data[inj_idx],
               color='red', s=70, zorder=6,
               label='Injected Anomaly (Ground Truth)')
    ax.scatter(detected_idx, s_data[detected_idx],
               color='limegreen', marker='x', s=130,
               linewidths=2.5, zorder=5,
               label='Detected (Robust Peer-Aware Model)')
    ax.set_title(
        f'{label} — Robust Peer-Aware | '
        f'Auto-Threshold={best_threshold:.3f} | '
        f'P={precision:.2f}  R={recall:.2f}  '
        f'F1={f1:.2f}  AUC={auc_roc:.2f}\n'
        f'Targets → P≥{TARGET_PRECISION}  '
        f'R≥{TARGET_RECALL}  F1≥{TARGET_F1}  AUC≥{TARGET_AUC_ROC}',
        fontsize=10
    )
    ax.set_xlabel('Time Step')
    ax.set_ylabel('Sensor Value')
    ax.grid(True, alpha=0.4)
    ax.legend(loc='upper left')

plt.tight_layout()
plt.savefig(os.path.join(REPORTS_DIR, 'sensor_anomalies_plot.png'),
            bbox_inches='tight', dpi=150)
plt.show()

fig, axes = plt.subplots(2, 1, figsize=(16, 9))
for ax, feats, inj_idx, label in zip(
    axes,
    [feats_1,  feats_2],
    [injected_anomaly_indices_1, injected_anomaly_indices_2],
    ['Sensor 1', 'Sensor 2']
):
    zscore = feats['robust_zscore']
    ax.plot(zscore, color='steelblue', alpha=0.7,
            linewidth=0.8, label='Robust Z-Score (Median+MAD)')
    ax.axhline(y= best_threshold, color='red', linewidth=2,
               linestyle='--',
               label=f'Auto-Learned +Threshold ({best_threshold:.3f})')
    ax.axhline(y=-best_threshold, color='red', linewidth=2,
               linestyle='--',
               label=f'Auto-Learned -Threshold ({best_threshold:.3f})')
    ax.axhspan(-best_threshold, best_threshold,
               alpha=0.08, color='green', label='Normal Zone')
    ax.scatter(inj_idx, zscore[inj_idx],
               color='red', s=50, zorder=5,
               label='True Anomaly Locations')
    ax.set_title(
        f'{label} — Robust Z-Score (Median+MAD) | '
        f'Window={ROLLING_WINDOW} | '
        f'Auto-Threshold={best_threshold:.3f}\n'
        f'True anomalies should clearly exceed the red lines'
    )
    ax.set_xlabel('Time Step')
    ax.set_ylabel('Robust Z-Score')
    ax.legend(loc='upper left', fontsize=8)
    ax.grid(True, alpha=0.4)

plt.tight_layout()
plt.savefig(os.path.join(REPORTS_DIR, 'robust_zscore_plot.png'),
            bbox_inches='tight', dpi=150)
plt.show()
# Out:
# Building robust peer-aware features (window=51)...
#   Using Median + MAD (robust to anomalies in window)...
#   Features built successfully!
#
# --- Feature Separation Diagnostics ---
#   Sensor 1 Robust Z-Score:
#     Normal  — mean: 0.757  max: 4.283
#     Anomaly — mean: 10.252  max: 33.635
#   Sensor 2 Robust Z-Score:
#     Normal  — mean: 0.772  max: 3.936
#     Anomaly — mean: 6.919  max: 20.601
#
# Training IsolationForest...
# Training complete!
#
# ============================================================
#   AUTO-LEARNING OPTIMAL THRESHOLD (WITH FLOOR CONSTRAINT)
# ============================================================
#   Search range : 0.50 → 22.32
#
#   ✅ Optimal threshold (auto-learned) : 4.3038
#      Best F1                          : 0.9931
#      Precision at best threshold      : 1.0000
#      Recall at best threshold         : 0.9863
# ============================================================
#         FINAL EVALUATION vs QUALITY TARGETS
# ============================================================
# Metric         Achieved     Target     Status
# ------------------------------------------------------------
# Precision        1.0000       0.85     ✅ PASS
# Recall           0.9863       0.85     ✅ PASS
# F1-Score         0.9931       0.85     ✅ PASS
# AUC-ROC          0.9998       0.90     ✅ PASS
# ============================================================
#
#   TP : 144  |  FP : 0  |  TN : 1354  |  FN : 2
# ✅ All required columns present in Predictions sheet:
#    • Sensor_1_Value            — sample value: 70.18857531560928
#    • Sensor_2_Value            — sample value: 57.349968067217425
#    • True_Anomaly              — sample value: 0
#    • Predicted_Anomaly         — sample value: 0
#    • Anomaly_Score             — sample value: -0.11273365999738227
#    • Is_Correct_Prediction     — sample value: True
#    • Prediction_Type           — sample value: TN
#
# ✅ Excel saved : anomaly_reports/anomaly_detection_report.xlsx
#    Sheet 1 — Training Data   : 1500 rows × 2 sensor columns
#    Sheet 2 — Predictions     : 1500 rows × 10 columns
#    Sheet 3 — Quality Metrics : Summary scores & pass/fail
#
# --- Predictions Sheet Preview (first 5 rows) ---
#            Sensor_1_Value  Sensor_2_Value  True_Anomaly  Predicted_Anomaly  Anomaly_Score  Is_Correct_Prediction Prediction_Type
# Time_Step
# 0               70.188575       57.349968             0                  0      -0.112734                   True              TN
# 1               69.701554       69.970734             1                  1       0.080436                   True              TP
# 2               69.413041       58.193222             0                  0      -0.040077                   True              TN
# 3               59.451747       58.410948             1                  1       0.120105                   True              TP
# 4               69.081930       58.511350             0                  0      -0.023663                   True              TN
#
# --- Prediction Type Counts ---
# Prediction_Type
# TN    1354
# TP     144
# FN       2

# %% [markdown]
# #Predictive Layer

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# IMPORTANT: This Block 3 code assumes 'df' (from Block 1) and 'data_for_model' (from Block 2)
# are already generated and available.
# 'df' should have 'sensor_1' and 'sensor_2' columns.
# 'data_for_model' should have the same index as 'df' and be ready for new columns.

# --- Configuration for Predictive Anomaly Detection ---

# Define when the system should start actively monitoring and alerting.
# This is set to 1050 to align with the degradation start and prevent early "crying wolf" alerts.
MONITORING_START = 1050

# Define the predictive horizon: how many steps into the future we predict.
# A value of 15 means we predict 15 time steps ahead.
PREDICTIVE_HORIZON = 15

# Define the alert thresholds for predicted values for each sensor.
# These are set slightly below the 'Danger Thresholds' (e.g., 74.0 for S1, 62.0 for S2)
# to provide an early warning before the system enters a critical state.
ALERT_THRESHOLD_S1 = 73.0 # For Sensor 1 (Pressure), predicting if it will exceed 73.0
ALERT_THRESHOLD_S2 = 61.0 # For Sensor 2 (Temperature), predicting if it will exceed 61.0

# Define the minimum number of data points required to calculate a reliable trend.
# A sufficient number of points helps in getting a stable slope for prediction.
MIN_TREND_POINTS = 30

# Define the size of the sliding window used for trend calculation.
# This window moves across the data, using the last 'window_size' points to calculate the current trend.
window_size = 60

# --- Initialize lists to store alert information and forecasted values ---
predictive_alerts = [] # This list will hold dictionaries, each representing an alert.

# Initialize columns for forecasts and alerts in data_for_model
# We use NaN for forecasts where no prediction is made (e.g., not enough data, or before monitoring starts)
# We use False for alerts by default, setting to True when an alert condition is met.
data_for_model['Forecast_S1'] = np.nan
data_for_model['Forecast_S2'] = np.nan
data_for_model['Pred_Alert_S1'] = False
data_for_model['Pred_Alert_S2'] = False

# --- Loop through the data to simulate real-time monitoring ---
print(f"Starting predictive monitoring simulation. Alerts will only be issued from t={MONITORING_START} onwards.")

for i in range(len(df)):
    current_time = df.index[i] # Get the current time step (index) from the DataFrame.

    # --- Step 1: Check if monitoring should be active ---
    if current_time < MONITORING_START:
        continue # Skip to the next time step in the loop.

    # --- Step 2: If monitoring is active, proceed with predictive analysis ---

    # Ensure there are enough historical data points to form a window for trend calculation.
    if i < MIN_TREND_POINTS:
        continue # Skip to the next time step.

    # Determine the starting index for the current sliding window.
    start_window_idx = max(0, i - window_size + 1)

    # Extract the relevant data for the current window.
    current_window_df = df.iloc[start_window_idx : i + 1]

    # --- Sensor 1 (Pressure) Analysis ---
    if len(current_window_df['sensor_1']) >= MIN_TREND_POINTS:
        x = np.arange(len(current_window_df))
        y_s1 = current_window_df['sensor_1'].values
        slope_s1, intercept_s1 = np.polyfit(x, y_s1, 1)

        predicted_value_s1 = intercept_s1 + slope_s1 * (len(current_window_df) + PREDICTIVE_HORIZON - 1)

        # Store the forecasted value in data_for_model
        data_for_model.loc[current_time, 'Forecast_S1'] = predicted_value_s1

        # Check for a predictive alert for Sensor 1.
        if predicted_value_s1 >= ALERT_THRESHOLD_S1:
            predictive_alerts.append({
                'time': current_time,
                'sensor': 'sensor_1',
                'predicted_value': predicted_value_s1,
                'alert_threshold': ALERT_THRESHOLD_S1,
                'message': f"PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach {predicted_value_s1:.2f} in {PREDICTIVE_HORIZON} steps, exceeding {ALERT_THRESHOLD_S1:.1f}!"
            })
            # Set the alert flag in data_for_model
            data_for_model.loc[current_time, 'Pred_Alert_S1'] = True

    # --- Sensor 2 (Temperature) Analysis ---
    if len(current_window_df['sensor_2']) >= MIN_TREND_POINTS:
        x = np.arange(len(current_window_df))
        y_s2 = current_window_df['sensor_2'].values
        slope_s2, intercept_s2 = np.polyfit(x, y_s2, 1)
        predicted_value_s2 = intercept_s2 + slope_s2 * (len(current_window_df) + PREDICTIVE_HORIZON - 1)

        # Store the forecasted value in data_for_model
        data_for_model.loc[current_time, 'Forecast_S2'] = predicted_value_s2

        # Check for a predictive alert for Sensor 2.
        if predicted_value_s2 >= ALERT_THRESHOLD_S2:
            predictive_alerts.append({
                'time': current_time,
                'sensor': 'sensor_2',
                'predicted_value': predicted_value_s2,
                'alert_threshold': ALERT_THRESHOLD_S2,
                'message': f"PREDICTIVE ALERT: Sensor 2 (Temperature) predicted to reach {predicted_value_s2:.2f} in {PREDICTIVE_HORIZON} steps, exceeding {ALERT_THRESHOLD_S2:.1f}!"
            })
            # Set the alert flag in data_for_model
            data_for_model.loc[current_time, 'Pred_Alert_S2'] = True

# --- Display All Predictive Alerts ---
print(f"\n--- Summary of Predictive Alerts (Monitoring started at t={MONITORING_START}) ---")
if predictive_alerts:
    predictive_alerts.sort(key=lambda x: x['time'])
    for alert in predictive_alerts:
        print(f"Time {alert['time']}: {alert['message']}")
else:
    print("No predictive alerts were issued after monitoring started at t=1050.")

print("\nPredictive alert and forecast data added to 'data_for_model' DataFrame.")
print("New columns in data_for_model:", [col for col in data_for_model.columns if 'Pred_Alert' in col or 'Forecast' in col])

# --- Optional: Visualizing Alerts (Integration with Block 2 Plotting) ---
# This section remains the same for reference, but the primary way Block 4 will use
# these alerts is directly from the new columns in 'data_for_model'.
alert_times_s1 = [a['time'] for a in predictive_alerts if a['sensor'] == 'sensor_1']
alert_times_s2 = [a['time'] for a in predictive_alerts if a['sensor'] == 'sensor_2']
# Out:
# Starting predictive monitoring simulation. Alerts will only be issued from t=1050 onwards.
#
# --- Summary of Predictive Alerts (Monitoring started at t=1050) ---
# Time 1050: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.33 in 15 steps, exceeding 73.0!
# Time 1051: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.22 in 15 steps, exceeding 73.0!
# Time 1052: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.66 in 15 steps, exceeding 73.0!
# Time 1053: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.71 in 15 steps, exceeding 73.0!
# Time 1054: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.71 in 15 steps, exceeding 73.0!
# Time 1055: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.63 in 15 steps, exceeding 73.0!
# Time 1056: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.67 in 15 steps, exceeding 73.0!
# Time 1057: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.60 in 15 steps, exceeding 73.0!
# Time 1058: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.48 in 15 steps, exceeding 73.0!
# Time 1059: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.49 in 15 steps, exceeding 73.0!
# Time 1060: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.53 in 15 steps, exceeding 73.0!
# Time 1061: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.58 in 15 steps, exceeding 73.0!
# Time 1062: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.53 in 15 steps, exceeding 73.0!
# Time 1063: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.12 in 15 steps, exceeding 73.0!
# Time 1064: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.05 in 15 steps, exceeding 73.0!
# Time 1065: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.09 in 15 steps, exceeding 73.0!
# Time 1066: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.04 in 15 steps, exceeding 73.0!
# Time 1067: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.02 in 15 steps, exceeding 73.0!
# Time 1068: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.99 in 15 steps, exceeding 73.0!
# Time 1069: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.99 in 15 steps, exceeding 73.0!
# Time 1070: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.40 in 15 steps, exceeding 73.0!
# Time 1071: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.48 in 15 steps, exceeding 73.0!
# Time 1072: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.43 in 15 steps, exceeding 73.0!
# Time 1073: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.41 in 15 steps, exceeding 73.0!
# Time 1074: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.44 in 15 steps, exceeding 73.0!
# Time 1075: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.44 in 15 steps, exceeding 73.0!
# Time 1076: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.49 in 15 steps, exceeding 73.0!
# Time 1077: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.46 in 15 steps, exceeding 73.0!
# Time 1078: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.42 in 15 steps, exceeding 73.0!
# Time 1079: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.44 in 15 steps, exceeding 73.0!
# Time 1080: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.48 in 15 steps, exceeding 73.0!
# Time 1081: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.40 in 15 steps, exceeding 73.0!
# Time 1082: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.31 in 15 steps, exceeding 73.0!
# Time 1083: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.33 in 15 steps, exceeding 73.0!
# Time 1084: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.27 in 15 steps, exceeding 73.0!
# Time 1085: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.19 in 15 steps, exceeding 73.0!
# Time 1086: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.13 in 15 steps, exceeding 73.0!
# Time 1087: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.12 in 15 steps, exceeding 73.0!
# Time 1088: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.13 in 15 steps, exceeding 73.0!
# Time 1089: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.10 in 15 steps, exceeding 73.0!
# Time 1090: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.07 in 15 steps, exceeding 73.0!
# Time 1091: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.04 in 15 steps, exceeding 73.0!
# Time 1092: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.15 in 15 steps, exceeding 73.0!
# Time 1093: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.14 in 15 steps, exceeding 73.0!
# Time 1094: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.14 in 15 steps, exceeding 73.0!
# Time 1095: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.05 in 15 steps, exceeding 73.0!
# Time 1096: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.04 in 15 steps, exceeding 73.0!
# Time 1097: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.02 in 15 steps, exceeding 73.0!
# Time 1098: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 74.98 in 15 steps, exceeding 73.0!
# Time 1099: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 74.95 in 15 steps, exceeding 73.0!
# Time 1100: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 74.98 in 15 steps, exceeding 73.0!
# Time 1101: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 74.98 in 15 steps, exceeding 73.0!
# Time 1102: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 74.22 in 15 steps, exceeding 73.0!
# Time 1103: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.11 in 15 steps, exceeding 73.0!
# Time 1104: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.15 in 15 steps, exceeding 73.0!
# Time 1105: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.16 in 15 steps, exceeding 73.0!
# Time 1106: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.10 in 15 steps, exceeding 73.0!
# Time 1107: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.04 in 15 steps, exceeding 73.0!
# Time 1108: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 74.99 in 15 steps, exceeding 73.0!
# Time 1109: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 74.99 in 15 steps, exceeding 73.0!
# Time 1110: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.00 in 15 steps, exceeding 73.0!
# Time 1111: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.55 in 15 steps, exceeding 73.0!
# Time 1112: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.54 in 15 steps, exceeding 73.0!
# Time 1113: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.60 in 15 steps, exceeding 73.0!
# Time 1114: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.58 in 15 steps, exceeding 73.0!
# Time 1115: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.58 in 15 steps, exceeding 73.0!
# Time 1116: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 74.75 in 15 steps, exceeding 73.0!
# Time 1117: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 74.82 in 15 steps, exceeding 73.0!
# Time 1118: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 74.84 in 15 steps, exceeding 73.0!
# Time 1119: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 74.89 in 15 steps, exceeding 73.0!
# Time 1120: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 74.97 in 15 steps, exceeding 73.0!
# Time 1121: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 74.97 in 15 steps, exceeding 73.0!
# Time 1122: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.57 in 15 steps, exceeding 73.0!
# Time 1123: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.60 in 15 steps, exceeding 73.0!
# Time 1124: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.58 in 15 steps, exceeding 73.0!
# Time 1125: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.62 in 15 steps, exceeding 73.0!
# Time 1126: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.62 in 15 steps, exceeding 73.0!
# Time 1127: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.70 in 15 steps, exceeding 73.0!
# Time 1128: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.73 in 15 steps, exceeding 73.0!
# Time 1129: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.83 in 15 steps, exceeding 73.0!
# Time 1130: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.85 in 15 steps, exceeding 73.0!
# Time 1131: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.91 in 15 steps, exceeding 73.0!
# Time 1132: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.39 in 15 steps, exceeding 73.0!
# Time 1133: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.42 in 15 steps, exceeding 73.0!
# Time 1134: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.46 in 15 steps, exceeding 73.0!
# Time 1135: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.45 in 15 steps, exceeding 73.0!
# Time 1136: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.54 in 15 steps, exceeding 73.0!
# Time 1137: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.53 in 15 steps, exceeding 73.0!
# Time 1138: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.60 in 15 steps, exceeding 73.0!
# Time 1139: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.60 in 15 steps, exceeding 73.0!
# Time 1140: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.53 in 15 steps, exceeding 73.0!
# Time 1141: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.54 in 15 steps, exceeding 73.0!
# Time 1142: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.55 in 15 steps, exceeding 73.0!
# Time 1143: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.57 in 15 steps, exceeding 73.0!
# Time 1144: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.70 in 15 steps, exceeding 73.0!
# Time 1145: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.75 in 15 steps, exceeding 73.0!
# Time 1146: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.78 in 15 steps, exceeding 73.0!
# Time 1147: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.79 in 15 steps, exceeding 73.0!
# Time 1148: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.82 in 15 steps, exceeding 73.0!
# Time 1149: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.72 in 15 steps, exceeding 73.0!
# Time 1150: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.76 in 15 steps, exceeding 73.0!
# Time 1151: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.82 in 15 steps, exceeding 73.0!
# Time 1152: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.95 in 15 steps, exceeding 73.0!
# Time 1153: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.92 in 15 steps, exceeding 73.0!
# Time 1154: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.88 in 15 steps, exceeding 73.0!
# Time 1155: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.83 in 15 steps, exceeding 73.0!
# Time 1156: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.96 in 15 steps, exceeding 73.0!
# Time 1157: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.01 in 15 steps, exceeding 73.0!
# Time 1158: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.05 in 15 steps, exceeding 73.0!
# Time 1159: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.05 in 15 steps, exceeding 73.0!
# Time 1160: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.03 in 15 steps, exceeding 73.0!
# Time 1161: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.08 in 15 steps, exceeding 73.0!
# Time 1162: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.74 in 15 steps, exceeding 73.0!
# Time 1163: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.28 in 15 steps, exceeding 73.0!
# Time 1164: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.37 in 15 steps, exceeding 73.0!
# Time 1165: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.55 in 15 steps, exceeding 73.0!
# Time 1166: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.51 in 15 steps, exceeding 73.0!
# Time 1167: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.49 in 15 steps, exceeding 73.0!
# Time 1168: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.50 in 15 steps, exceeding 73.0!
# Time 1169: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.67 in 15 steps, exceeding 73.0!
# Time 1170: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.79 in 15 steps, exceeding 73.0!
# Time 1171: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.87 in 15 steps, exceeding 73.0!
# Time 1172: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.89 in 15 steps, exceeding 73.0!
# Time 1173: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.92 in 15 steps, exceeding 73.0!
# Time 1174: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.87 in 15 steps, exceeding 73.0!
# Time 1175: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.93 in 15 steps, exceeding 73.0!
# Time 1176: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.38 in 15 steps, exceeding 73.0!
# Time 1177: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.43 in 15 steps, exceeding 73.0!
# Time 1178: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.46 in 15 steps, exceeding 73.0!
# Time 1179: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.37 in 15 steps, exceeding 73.0!
# Time 1180: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.43 in 15 steps, exceeding 73.0!
# Time 1181: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.47 in 15 steps, exceeding 73.0!
# Time 1182: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.40 in 15 steps, exceeding 73.0!
# Time 1183: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.37 in 15 steps, exceeding 73.0!
# Time 1184: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.40 in 15 steps, exceeding 73.0!
# Time 1185: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.32 in 15 steps, exceeding 73.0!
# Time 1186: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.26 in 15 steps, exceeding 73.0!
# Time 1187: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.27 in 15 steps, exceeding 73.0!
# Time 1188: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.31 in 15 steps, exceeding 73.0!
# Time 1189: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.29 in 15 steps, exceeding 73.0!
# Time 1190: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.32 in 15 steps, exceeding 73.0!
# Time 1191: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.13 in 15 steps, exceeding 73.0!
# Time 1192: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.15 in 15 steps, exceeding 73.0!
# Time 1193: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.21 in 15 steps, exceeding 73.0!
# Time 1194: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.26 in 15 steps, exceeding 73.0!
# Time 1195: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.25 in 15 steps, exceeding 73.0!
# Time 1196: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.46 in 15 steps, exceeding 73.0!
# Time 1197: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 74.77 in 15 steps, exceeding 73.0!
# Time 1198: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 74.75 in 15 steps, exceeding 73.0!
# Time 1199: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 74.75 in 15 steps, exceeding 73.0!
# Time 1200: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 74.69 in 15 steps, exceeding 73.0!
# Time 1201: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 74.67 in 15 steps, exceeding 73.0!
# Time 1202: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 74.68 in 15 steps, exceeding 73.0!
# Time 1203: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 74.77 in 15 steps, exceeding 73.0!
# Time 1204: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 74.89 in 15 steps, exceeding 73.0!
# Time 1205: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 74.93 in 15 steps, exceeding 73.0!
# Time 1206: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.02 in 15 steps, exceeding 73.0!
# Time 1207: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.06 in 15 steps, exceeding 73.0!
# Time 1208: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.15 in 15 steps, exceeding 73.0!
# Time 1209: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.12 in 15 steps, exceeding 73.0!
# Time 1210: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.23 in 15 steps, exceeding 73.0!
# Time 1211: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.26 in 15 steps, exceeding 73.0!
# Time 1212: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.26 in 15 steps, exceeding 73.0!
# Time 1213: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.21 in 15 steps, exceeding 73.0!
# Time 1214: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.28 in 15 steps, exceeding 73.0!
# Time 1215: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.28 in 15 steps, exceeding 73.0!
# Time 1216: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.33 in 15 steps, exceeding 73.0!
# Time 1217: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.36 in 15 steps, exceeding 73.0!
# Time 1218: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.44 in 15 steps, exceeding 73.0!
# Time 1219: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.51 in 15 steps, exceeding 73.0!
# Time 1220: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.40 in 15 steps, exceeding 73.0!
# Time 1221: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.45 in 15 steps, exceeding 73.0!
# Time 1222: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.52 in 15 steps, exceeding 73.0!
# Time 1223: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.50 in 15 steps, exceeding 73.0!
# Time 1224: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.51 in 15 steps, exceeding 73.0!
# Time 1225: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.63 in 15 steps, exceeding 73.0!
# Time 1226: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.64 in 15 steps, exceeding 73.0!
# Time 1227: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.69 in 15 steps, exceeding 73.0!
# Time 1228: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.69 in 15 steps, exceeding 73.0!
# Time 1229: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.81 in 15 steps, exceeding 73.0!
# Time 1230: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.80 in 15 steps, exceeding 73.0!
# Time 1231: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.86 in 15 steps, exceeding 73.0!
# Time 1232: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.83 in 15 steps, exceeding 73.0!
# Time 1233: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.80 in 15 steps, exceeding 73.0!
# Time 1234: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.75 in 15 steps, exceeding 73.0!
# Time 1235: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.79 in 15 steps, exceeding 73.0!
# Time 1236: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.75 in 15 steps, exceeding 73.0!
# Time 1237: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.73 in 15 steps, exceeding 73.0!
# Time 1238: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.85 in 15 steps, exceeding 73.0!
# Time 1239: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.87 in 15 steps, exceeding 73.0!
# Time 1240: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.89 in 15 steps, exceeding 73.0!
# Time 1241: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.03 in 15 steps, exceeding 73.0!
# Time 1242: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.91 in 15 steps, exceeding 73.0!
# Time 1243: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.94 in 15 steps, exceeding 73.0!
# Time 1244: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.04 in 15 steps, exceeding 73.0!
# Time 1245: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.01 in 15 steps, exceeding 73.0!
# Time 1246: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.03 in 15 steps, exceeding 73.0!
# Time 1247: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.17 in 15 steps, exceeding 73.0!
# Time 1248: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.19 in 15 steps, exceeding 73.0!
# Time 1249: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.16 in 15 steps, exceeding 73.0!
# Time 1250: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.28 in 15 steps, exceeding 73.0!
# Time 1251: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.26 in 15 steps, exceeding 73.0!
# Time 1252: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.34 in 15 steps, exceeding 73.0!
# Time 1253: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.38 in 15 steps, exceeding 73.0!
# Time 1254: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.44 in 15 steps, exceeding 73.0!
# Time 1255: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.57 in 15 steps, exceeding 73.0!
# Time 1256: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.08 in 15 steps, exceeding 73.0!
# Time 1257: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.66 in 15 steps, exceeding 73.0!
# Time 1258: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.65 in 15 steps, exceeding 73.0!
# Time 1259: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.67 in 15 steps, exceeding 73.0!
# Time 1260: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.59 in 15 steps, exceeding 73.0!
# Time 1261: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.53 in 15 steps, exceeding 73.0!
# Time 1262: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.47 in 15 steps, exceeding 73.0!
# Time 1263: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 74.69 in 15 steps, exceeding 73.0!
# Time 1264: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 74.70 in 15 steps, exceeding 73.0!
# Time 1265: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 74.74 in 15 steps, exceeding 73.0!
# Time 1266: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 74.78 in 15 steps, exceeding 73.0!
# Time 1267: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 74.88 in 15 steps, exceeding 73.0!
# Time 1268: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 74.96 in 15 steps, exceeding 73.0!
# Time 1269: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 74.94 in 15 steps, exceeding 73.0!
# Time 1270: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.09 in 15 steps, exceeding 73.0!
# Time 1271: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.08 in 15 steps, exceeding 73.0!
# Time 1272: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.09 in 15 steps, exceeding 73.0!
# Time 1273: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.11 in 15 steps, exceeding 73.0!
# Time 1274: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.22 in 15 steps, exceeding 73.0!
# Time 1275: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.26 in 15 steps, exceeding 73.0!
# Time 1276: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.28 in 15 steps, exceeding 73.0!
# Time 1277: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.31 in 15 steps, exceeding 73.0!
# Time 1278: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 75.99 in 15 steps, exceeding 73.0!
# Time 1279: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.15 in 15 steps, exceeding 73.0!
# Time 1280: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.22 in 15 steps, exceeding 73.0!
# Time 1281: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.35 in 15 steps, exceeding 73.0!
# Time 1282: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.45 in 15 steps, exceeding 73.0!
# Time 1283: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.56 in 15 steps, exceeding 73.0!
# Time 1284: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.62 in 15 steps, exceeding 73.0!
# Time 1285: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.72 in 15 steps, exceeding 73.0!
# Time 1286: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.77 in 15 steps, exceeding 73.0!
# Time 1287: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.92 in 15 steps, exceeding 73.0!
# Time 1288: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.93 in 15 steps, exceeding 73.0!
# Time 1289: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.11 in 15 steps, exceeding 73.0!
# Time 1290: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.12 in 15 steps, exceeding 73.0!
# Time 1291: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.23 in 15 steps, exceeding 73.0!
# Time 1292: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.28 in 15 steps, exceeding 73.0!
# Time 1293: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.27 in 15 steps, exceeding 73.0!
# Time 1294: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.29 in 15 steps, exceeding 73.0!
# Time 1295: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.35 in 15 steps, exceeding 73.0!
# Time 1296: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.76 in 15 steps, exceeding 73.0!
# Time 1297: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.89 in 15 steps, exceeding 73.0!
# Time 1298: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.93 in 15 steps, exceeding 73.0!
# Time 1299: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.98 in 15 steps, exceeding 73.0!
# Time 1300: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.94 in 15 steps, exceeding 73.0!
# Time 1301: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.02 in 15 steps, exceeding 73.0!
# Time 1302: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.84 in 15 steps, exceeding 73.0!
# Time 1303: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.86 in 15 steps, exceeding 73.0!
# Time 1304: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.82 in 15 steps, exceeding 73.0!
# Time 1305: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.78 in 15 steps, exceeding 73.0!
# Time 1306: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.71 in 15 steps, exceeding 73.0!
# Time 1307: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.78 in 15 steps, exceeding 73.0!
# Time 1308: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.72 in 15 steps, exceeding 73.0!
# Time 1309: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.81 in 15 steps, exceeding 73.0!
# Time 1310: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.82 in 15 steps, exceeding 73.0!
# Time 1311: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.84 in 15 steps, exceeding 73.0!
# Time 1312: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.90 in 15 steps, exceeding 73.0!
# Time 1313: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.92 in 15 steps, exceeding 73.0!
# Time 1314: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.88 in 15 steps, exceeding 73.0!
# Time 1315: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.94 in 15 steps, exceeding 73.0!
# Time 1316: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.94 in 15 steps, exceeding 73.0!
# Time 1317: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.88 in 15 steps, exceeding 73.0!
# Time 1318: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.90 in 15 steps, exceeding 73.0!
# Time 1319: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.91 in 15 steps, exceeding 73.0!
# Time 1320: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.88 in 15 steps, exceeding 73.0!
# Time 1321: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.87 in 15 steps, exceeding 73.0!
# Time 1322: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.82 in 15 steps, exceeding 73.0!
# Time 1323: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.35 in 15 steps, exceeding 73.0!
# Time 1324: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.33 in 15 steps, exceeding 73.0!
# Time 1325: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.38 in 15 steps, exceeding 73.0!
# Time 1326: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.40 in 15 steps, exceeding 73.0!
# Time 1327: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.45 in 15 steps, exceeding 73.0!
# Time 1328: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.38 in 15 steps, exceeding 73.0!
# Time 1329: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.32 in 15 steps, exceeding 73.0!
# Time 1330: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.35 in 15 steps, exceeding 73.0!
# Time 1331: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.33 in 15 steps, exceeding 73.0!
# Time 1332: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.40 in 15 steps, exceeding 73.0!
# Time 1333: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.42 in 15 steps, exceeding 73.0!
# Time 1334: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.41 in 15 steps, exceeding 73.0!
# Time 1335: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.44 in 15 steps, exceeding 73.0!
# Time 1336: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.41 in 15 steps, exceeding 73.0!
# Time 1337: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.34 in 15 steps, exceeding 73.0!
# Time 1338: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.43 in 15 steps, exceeding 73.0!
# Time 1339: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.45 in 15 steps, exceeding 73.0!
# Time 1340: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.50 in 15 steps, exceeding 73.0!
# Time 1341: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.50 in 15 steps, exceeding 73.0!
# Time 1342: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.56 in 15 steps, exceeding 73.0!
# Time 1343: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.61 in 15 steps, exceeding 73.0!
# Time 1344: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.68 in 15 steps, exceeding 73.0!
# Time 1345: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.76 in 15 steps, exceeding 73.0!
# Time 1346: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.76 in 15 steps, exceeding 73.0!
# Time 1347: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.82 in 15 steps, exceeding 73.0!
# Time 1348: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.76 in 15 steps, exceeding 73.0!
# Time 1349: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.73 in 15 steps, exceeding 73.0!
# Time 1350: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.71 in 15 steps, exceeding 73.0!
# Time 1351: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.74 in 15 steps, exceeding 73.0!
# Time 1352: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.75 in 15 steps, exceeding 73.0!
# Time 1353: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.78 in 15 steps, exceeding 73.0!
# Time 1354: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.79 in 15 steps, exceeding 73.0!
# Time 1355: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.77 in 15 steps, exceeding 73.0!
# Time 1356: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.78 in 15 steps, exceeding 73.0!
# Time 1357: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.92 in 15 steps, exceeding 73.0!
# Time 1358: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.82 in 15 steps, exceeding 73.0!
# Time 1359: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.71 in 15 steps, exceeding 73.0!
# Time 1360: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.67 in 15 steps, exceeding 73.0!
# Time 1361: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.63 in 15 steps, exceeding 73.0!
# Time 1362: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 78.22 in 15 steps, exceeding 73.0!
# Time 1363: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 78.27 in 15 steps, exceeding 73.0!
# Time 1364: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 78.22 in 15 steps, exceeding 73.0!
# Time 1365: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 78.32 in 15 steps, exceeding 73.0!
# Time 1366: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 78.31 in 15 steps, exceeding 73.0!
# Time 1367: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 78.36 in 15 steps, exceeding 73.0!
# Time 1368: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 78.39 in 15 steps, exceeding 73.0!
# Time 1369: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.85 in 15 steps, exceeding 73.0!
# Time 1370: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.78 in 15 steps, exceeding 73.0!
# Time 1371: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.74 in 15 steps, exceeding 73.0!
# Time 1372: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.78 in 15 steps, exceeding 73.0!
# Time 1373: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.77 in 15 steps, exceeding 73.0!
# Time 1374: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.76 in 15 steps, exceeding 73.0!
# Time 1375: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.70 in 15 steps, exceeding 73.0!
# Time 1376: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.68 in 15 steps, exceeding 73.0!
# Time 1377: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.58 in 15 steps, exceeding 73.0!
# Time 1378: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.56 in 15 steps, exceeding 73.0!
# Time 1379: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.42 in 15 steps, exceeding 73.0!
# Time 1380: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.38 in 15 steps, exceeding 73.0!
# Time 1381: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.33 in 15 steps, exceeding 73.0!
# Time 1382: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.19 in 15 steps, exceeding 73.0!
# Time 1383: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.17 in 15 steps, exceeding 73.0!
# Time 1384: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.15 in 15 steps, exceeding 73.0!
# Time 1385: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.23 in 15 steps, exceeding 73.0!
# Time 1386: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.29 in 15 steps, exceeding 73.0!
# Time 1387: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.24 in 15 steps, exceeding 73.0!
# Time 1388: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.21 in 15 steps, exceeding 73.0!
# Time 1389: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.22 in 15 steps, exceeding 73.0!
# Time 1390: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.17 in 15 steps, exceeding 73.0!
# Time 1391: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.19 in 15 steps, exceeding 73.0!
# Time 1392: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.25 in 15 steps, exceeding 73.0!
# Time 1393: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.14 in 15 steps, exceeding 73.0!
# Time 1394: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.07 in 15 steps, exceeding 73.0!
# Time 1395: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.01 in 15 steps, exceeding 73.0!
# Time 1396: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.92 in 15 steps, exceeding 73.0!
# Time 1397: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.93 in 15 steps, exceeding 73.0!
# Time 1398: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.04 in 15 steps, exceeding 73.0!
# Time 1399: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.09 in 15 steps, exceeding 73.0!
# Time 1400: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.09 in 15 steps, exceeding 73.0!
# Time 1401: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.07 in 15 steps, exceeding 73.0!
# Time 1402: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.03 in 15 steps, exceeding 73.0!
# Time 1403: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.11 in 15 steps, exceeding 73.0!
# Time 1404: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.12 in 15 steps, exceeding 73.0!
# Time 1405: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.09 in 15 steps, exceeding 73.0!
# Time 1406: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.10 in 15 steps, exceeding 73.0!
# Time 1407: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.06 in 15 steps, exceeding 73.0!
# Time 1408: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.06 in 15 steps, exceeding 73.0!
# Time 1409: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.06 in 15 steps, exceeding 73.0!
# Time 1410: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.94 in 15 steps, exceeding 73.0!
# Time 1411: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.98 in 15 steps, exceeding 73.0!
# Time 1412: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.96 in 15 steps, exceeding 73.0!
# Time 1413: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.86 in 15 steps, exceeding 73.0!
# Time 1414: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.87 in 15 steps, exceeding 73.0!
# Time 1415: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.82 in 15 steps, exceeding 73.0!
# Time 1416: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.74 in 15 steps, exceeding 73.0!
# Time 1417: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.68 in 15 steps, exceeding 73.0!
# Time 1418: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 78.21 in 15 steps, exceeding 73.0!
# Time 1419: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 78.09 in 15 steps, exceeding 73.0!
# Time 1420: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 78.02 in 15 steps, exceeding 73.0!
# Time 1421: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.97 in 15 steps, exceeding 73.0!
# Time 1422: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.98 in 15 steps, exceeding 73.0!
# Time 1423: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.96 in 15 steps, exceeding 73.0!
# Time 1424: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.93 in 15 steps, exceeding 73.0!
# Time 1425: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.93 in 15 steps, exceeding 73.0!
# Time 1426: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.98 in 15 steps, exceeding 73.0!
# Time 1427: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.91 in 15 steps, exceeding 73.0!
# Time 1428: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.92 in 15 steps, exceeding 73.0!
# Time 1429: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.89 in 15 steps, exceeding 73.0!
# Time 1430: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.87 in 15 steps, exceeding 73.0!
# Time 1431: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.88 in 15 steps, exceeding 73.0!
# Time 1432: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.86 in 15 steps, exceeding 73.0!
# Time 1433: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.85 in 15 steps, exceeding 73.0!
# Time 1434: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.81 in 15 steps, exceeding 73.0!
# Time 1435: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.73 in 15 steps, exceeding 73.0!
# Time 1436: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.80 in 15 steps, exceeding 73.0!
# Time 1437: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.74 in 15 steps, exceeding 73.0!
# Time 1438: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.82 in 15 steps, exceeding 73.0!
# Time 1439: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.74 in 15 steps, exceeding 73.0!
# Time 1440: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.75 in 15 steps, exceeding 73.0!
# Time 1441: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.74 in 15 steps, exceeding 73.0!
# Time 1442: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.71 in 15 steps, exceeding 73.0!
# Time 1443: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.73 in 15 steps, exceeding 73.0!
# Time 1444: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.67 in 15 steps, exceeding 73.0!
# Time 1445: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.59 in 15 steps, exceeding 73.0!
# Time 1446: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.64 in 15 steps, exceeding 73.0!
# Time 1447: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.60 in 15 steps, exceeding 73.0!
# Time 1448: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.62 in 15 steps, exceeding 73.0!
# Time 1449: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.63 in 15 steps, exceeding 73.0!
# Time 1450: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.55 in 15 steps, exceeding 73.0!
# Time 1451: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.55 in 15 steps, exceeding 73.0!
# Time 1452: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.50 in 15 steps, exceeding 73.0!
# Time 1453: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.41 in 15 steps, exceeding 73.0!
# Time 1454: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.35 in 15 steps, exceeding 73.0!
# Time 1455: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.31 in 15 steps, exceeding 73.0!
# Time 1456: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.26 in 15 steps, exceeding 73.0!
# Time 1457: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.38 in 15 steps, exceeding 73.0!
# Time 1458: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.50 in 15 steps, exceeding 73.0!
# Time 1459: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.95 in 15 steps, exceeding 73.0!
# Time 1460: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.93 in 15 steps, exceeding 73.0!
# Time 1461: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.96 in 15 steps, exceeding 73.0!
# Time 1462: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.84 in 15 steps, exceeding 73.0!
# Time 1463: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.89 in 15 steps, exceeding 73.0!
# Time 1464: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.87 in 15 steps, exceeding 73.0!
# Time 1465: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.80 in 15 steps, exceeding 73.0!
# Time 1466: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.79 in 15 steps, exceeding 73.0!
# Time 1467: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.78 in 15 steps, exceeding 73.0!
# Time 1468: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 76.74 in 15 steps, exceeding 73.0!
# Time 1469: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.38 in 15 steps, exceeding 73.0!
# Time 1470: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.26 in 15 steps, exceeding 73.0!
# Time 1471: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 77.25 in 15 steps, exceeding 73.0!
# Time 1472: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 78.16 in 15 steps, exceeding 73.0!
# Time 1473: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 78.69 in 15 steps, exceeding 73.0!
# Time 1474: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 78.80 in 15 steps, exceeding 73.0!
# Time 1475: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 78.78 in 15 steps, exceeding 73.0!
# Time 1476: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 78.72 in 15 steps, exceeding 73.0!
# Time 1477: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 78.61 in 15 steps, exceeding 73.0!
# Time 1478: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 78.56 in 15 steps, exceeding 73.0!
# Time 1479: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 78.53 in 15 steps, exceeding 73.0!
# Time 1480: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 78.51 in 15 steps, exceeding 73.0!
# Time 1481: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 78.45 in 15 steps, exceeding 73.0!
# Time 1482: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 78.41 in 15 steps, exceeding 73.0!
# Time 1483: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 78.33 in 15 steps, exceeding 73.0!
# Time 1484: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 78.32 in 15 steps, exceeding 73.0!
# Time 1485: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 78.21 in 15 steps, exceeding 73.0!
# Time 1486: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 78.27 in 15 steps, exceeding 73.0!
# Time 1487: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 78.24 in 15 steps, exceeding 73.0!
# Time 1488: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 78.20 in 15 steps, exceeding 73.0!
# Time 1489: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 78.10 in 15 steps, exceeding 73.0!
# Time 1490: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 78.95 in 15 steps, exceeding 73.0!
# Time 1491: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 78.95 in 15 steps, exceeding 73.0!
# Time 1492: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 78.82 in 15 steps, exceeding 73.0!
# Time 1493: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 78.75 in 15 steps, exceeding 73.0!
# Time 1494: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 78.66 in 15 steps, exceeding 73.0!
# Time 1495: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 78.56 in 15 steps, exceeding 73.0!
# Time 1496: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 79.35 in 15 steps, exceeding 73.0!
# Time 1497: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 79.23 in 15 steps, exceeding 73.0!
# Time 1498: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 79.26 in 15 steps, exceeding 73.0!
# Time 1499: PREDICTIVE ALERT: Sensor 1 (Pressure) predicted to reach 79.19 in 15 steps, exceeding 73.0!
#
# Predictive alert and forecast data added to 'data_for_model' DataFrame.
# New columns in data_for_model: ['Forecast_S1', 'Forecast_S2', 'Pred_Alert_S1', 'Pred_Alert_S2']

# %% [markdown]
# #Visualization

# %%
# ─────────────────────────────────────────────
# BLOCK 4 — Visualise Layer 1 + Layer 2
#           Combined Chart — CLEAN REWRITE
# ─────────────────────────────────────────────

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# ===========================================================
# CONFIGURATION — All settings in one place
# ===========================================================

# ✅ Sensor-specific danger thresholds (must match Block 3)
DANGER_THRESHOLD_S1 = 74.0
DANGER_THRESHOLD_S2 = 62.0

# ✅ Y-axis range — covers both sensor value ranges comfortably
SENSOR_Y_MIN = 45
SENSOR_Y_MAX = 90

# ✅ Zone boundaries as % of total time steps
NORMAL_END   = int(N_SAMPLES * 0.70)   # 0   → 70%  = Normal Zone
PRE_FAIL_END = int(N_SAMPLES * 0.90)   # 70% → 90%  = Pre-Failure Zone
                                        # 90% → 100% = Failure Zone

# ===========================================================
# BUILD UNIFIED DATAFRAME — single source of truth
# ===========================================================

df = pd.DataFrame({
    'Time'         : np.arange(N_SAMPLES),

    # Raw sensor readings from Block 1
    'Sensor1'      : sensor_1_data,
    'Sensor2'      : sensor_2_data,

    # Anomaly flags from Block 2 (True = anomaly detected)
    'Anomaly_S1'   : (data_for_model['is_anomaly'] == -1).values,
    'Anomaly_S2'   : (data_for_model['is_anomaly'] == -1).values,

    # Predictive alert flags from Block 3
    'Pred_Alert_S1': data_for_model['Pred_Alert_S1'].values,
    'Pred_Alert_S2': data_for_model['Pred_Alert_S2'].values,

    # Forecasted values from Block 3
    'Forecast_S1'  : data_for_model['Forecast_S1'].values,
    'Forecast_S2'  : data_for_model['Forecast_S2'].values,
})

# ===========================================================
# FIND FIRST PREDICTIVE ALERT FOR EACH SENSOR
# ===========================================================

s1_alerts     = df[df['Pred_Alert_S1'] == True]
s2_alerts     = df[df['Pred_Alert_S2'] == True]

first_pred_s1 = s1_alerts['Time'].min() if len(s1_alerts) > 0 else None
first_pred_s2 = s2_alerts['Time'].min() if len(s2_alerts) > 0 else None

print(f"  Sensor 1 — First predictive alert : {first_pred_s1}")
print(f"  Sensor 2 — First predictive alert : {first_pred_s2}")

# ===========================================================
# CHART CONFIGURATION — Parallel lists, one entry per sensor
# ===========================================================

chart_config = [
    {
        'sensor_col'       : 'Sensor1',
        'anomaly_col'      : 'Anomaly_S1',
        'pred_alert_col'   : 'Pred_Alert_S1',
        'first_pred'       : first_pred_s1,
        'danger_threshold' : DANGER_THRESHOLD_S1,
        'title'            : 'Sensor 1 — Upstream Pipeline (Trending)',
        'color'            : 'steelblue',
    },
    {
        'sensor_col'       : 'Sensor2',
        'anomaly_col'      : 'Anomaly_S2',
        'pred_alert_col'   : 'Pred_Alert_S2',
        'first_pred'       : first_pred_s2,
        'danger_threshold' : DANGER_THRESHOLD_S2,
        'title'            : 'Sensor 2 — Midstream Pipeline (Stable)',
        'color'            : 'mediumpurple',
    },
]

# ===========================================================
# PLOT
# ===========================================================

fig, axes = plt.subplots(2, 1, figsize=(16, 12))
fig.suptitle(
    'Intelligent Pipeline Guardian\n'
    'Layer 1: Anomaly Detection  +  Layer 2: Predictive Alerts',
    fontsize=16, fontweight='bold', y=0.98
)

for ax, cfg in zip(axes, chart_config):

    sensor_col        = cfg['sensor_col']
    anomaly_col       = cfg['anomaly_col']
    danger_threshold  = cfg['danger_threshold']
    first_pred        = cfg['first_pred']

    # --- 1. Background zone shading ---
    ax.axvspan(0,            NORMAL_END,   alpha=0.08,
               color='green',  label='Normal Zone')
    ax.axvspan(NORMAL_END,   PRE_FAIL_END, alpha=0.08,
               color='orange', label='Pre-Failure Zone')
    ax.axvspan(PRE_FAIL_END, N_SAMPLES,    alpha=0.08,
               color='red',    label='Failure Zone')

    # --- 2. Danger threshold line ---
    ax.axhline(
        y=danger_threshold,
        color='red', linestyle='--',
        linewidth=1.5, alpha=0.7,
        label=f'Danger Threshold ({danger_threshold})'
    )

    # --- 3. Actual sensor readings ---
    ax.plot(
        df['Time'], df[sensor_col],
        color=cfg['color'], linewidth=1.0,
        alpha=0.85, label='Sensor Reading', zorder=3
    )

    # --- 4. Layer 1 — Detected anomaly points ---
    anomaly_rows = df[df[anomaly_col] == True]
    ax.scatter(
        anomaly_rows['Time'],
        anomaly_rows[sensor_col],
        color='red', s=60, zorder=5,
        label=f'🚨 Anomaly Detected (Layer 1) — {len(anomaly_rows)} points'
    )

    # --- 5. Layer 2 — First predictive alert marker ---
    if first_pred is not None and not pd.isna(first_pred):

        first_pred = int(first_pred)

        ax.axvline(
            x=first_pred,
            color='darkorange', linestyle='-.',
            linewidth=2, zorder=4,
            label=f'🔮 Predictive Alert at t={first_pred}'
        )

        # Safe annotation position
        sensor_val_at_pred = df[sensor_col].iloc[first_pred]
        annotation_x       = max(first_pred - 150, 10)
        annotation_y       = min(sensor_val_at_pred + 3, SENSOR_Y_MAX - 5)

        ax.annotate(
            f'⚠️ Trend Alert!\nt = {first_pred}',
            xy=(first_pred, sensor_val_at_pred),
            xytext=(annotation_x, annotation_y),
            fontsize=9, color='darkorange', fontweight='bold',
            arrowprops=dict(arrowstyle='->', color='darkorange', lw=1.5)
        )

    else:
        # No alert triggered — add info to legend
        ax.plot([], [], ' ',
                label='🔮 No Predictive Alert Triggered')

    # --- 6. Axis formatting ---
    ax.set_title(cfg['title'], fontsize=13, fontweight='bold')
    ax.set_xlabel('Time Steps', fontsize=10)
    ax.set_ylabel('Sensor Value', fontsize=10)
    ax.set_xlim(0, N_SAMPLES)
    ax.set_ylim(SENSOR_Y_MIN, SENSOR_Y_MAX)
    ax.legend(loc='upper left', fontsize=8)
    ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('pipeline_guardian.png', dpi=150, bbox_inches='tight')
plt.show()

print("✅ Block 4 Complete — Chart saved as pipeline_guardian.png!")

# ===========================================================
# SUMMARY REPORT
# ===========================================================

print("\n" + "="*55)
print("      INTELLIGENT PIPELINE GUARDIAN — SUMMARY")
print("="*55)

summary_config = [
    ('Sensor 1', first_pred_s1, DANGER_THRESHOLD_S1),
    ('Sensor 2', first_pred_s2, DANGER_THRESHOLD_S2),
]

for sensor_name, first_pred, threshold in summary_config:

    print(f"\n  {sensor_name}:")
    print(f"    🎯 Danger Threshold     : {threshold}")

    if first_pred is not None and not pd.isna(first_pred):
        steps_remaining = N_SAMPLES - int(first_pred)
        print(f"    🔮 Predictive alert at  : t = {int(first_pred)}")
        print(f"    ⏱️  Steps before end     : {steps_remaining} steps early!")
    else:
        print(f"    ℹ️  No predictive alert triggered")
        print(f"    💡 Threshold may be too high for this sensor's range")

print("\n" + "="*55)
print("  Layer 1 + Layer 2 = Complete Pipeline Protection!")
print("="*55)
# Out:
#   Sensor 1 — First predictive alert : 1050
#   Sensor 2 — First predictive alert : None
# /tmp/ipykernel_638/3658894585.py:178: UserWarning: Glyph 128680 (\N{POLICE CARS REVOLVING LIGHT}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_638/3658894585.py:178: UserWarning: Glyph 128302 (\N{CRYSTAL BALL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_638/3658894585.py:179: UserWarning: Glyph 128680 (\N{POLICE CARS REVOLVING LIGHT}) missing from font(s) DejaVu Sans.
#   plt.savefig('pipeline_guardian.png', dpi=150, bbox_inches='tight')
# /tmp/ipykernel_638/3658894585.py:179: UserWarning: Glyph 128302 (\N{CRYSTAL BALL}) missing from font(s) DejaVu Sans.
#   plt.savefig('pipeline_guardian.png', dpi=150, bbox_inches='tight')
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128680 (\N{POLICE CARS REVOLVING LIGHT}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128302 (\N{CRYSTAL BALL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ✅ Block 4 Complete — Chart saved as pipeline_guardian.png!
#
# =======================================================
#       INTELLIGENT PIPELINE GUARDIAN — SUMMARY
# =======================================================
#
#   Sensor 1:
#     🎯 Danger Threshold     : 74.0
#     🔮 Predictive alert at  : t = 1050
#     ⏱️  Steps before end     : 450 steps early!
#
#   Sensor 2:
#     🎯 Danger Threshold     : 62.0
#     ℹ️  No predictive alert triggered
#     💡 Threshold may be too high for this sensor's range
#
# =======================================================
#   Layer 1 + Layer 2 = Complete Pipeline Protection!
# =======================================================
